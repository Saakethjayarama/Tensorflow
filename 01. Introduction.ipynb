# %% [markdown]
# ## Keras

# %% [markdown]
# Keras is a high level Neural network API. Keras acts as a wrapper to lower lever neural network APIs namely Tensorflow, Theano and CNTK.
# Keras is now completely integrated with Tensorflow API.

# %%
## To find the number of GPUs
import tensorflow as tf
tf.config.experimental.list_physical_devices('GPU')
# Out:
# []
